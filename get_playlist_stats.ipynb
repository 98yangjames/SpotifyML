# %%
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy

# %%
df = pd.read_csv('Data/Playlist_Data/playlist.csv')
df.head(2)
# Out:
#    Unnamed: 0             trackName                                   uri
# 0           0  Last Kiss Of Nebulon  spotify:track:29Hn3L56DQ6y7W249oVxqd
# 1           1         Lady Of Namek  spotify:track:6ieWL5CLN9WdC875guWtMe

# %%
cid = '7cda6c1856a24d109ba5521fd35fd5a3'
secret = 'ac6d7cd270aa48cab17e179262d78031'

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
stats = pd.DataFrame()
for i in df['uri']:    
    song_stats = pd.DataFrame.from_dict(sp.audio_features(i)).drop(['type', 'mode', 'id', 'uri', 'track_href', 'analysis_url', 'time_signature', 'duration_ms'], axis = 1)
    stats = stats.append(song_stats)
# Out:
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)
# C:\Users\yangj\AppData\Local\Temp\ipykernel_2084\3085666081.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(song_stats)

# %%
stats
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.619   0.837   11    -7.665       0.0573        0.0356
# 0         0.676   0.659   11    -5.123       0.0476        0.1940
# 0         0.607   0.735    4    -6.065       0.0950        0.2530
# 0         0.645   0.534    6   -10.800       0.0479        0.1570
# 0         0.806   0.557    9    -6.007       0.0767        0.1840
# 0         0.701   0.782    1    -4.987       0.1380        0.0918
# 0         0.763   0.667    2    -6.285       0.0850        0.0210
# 0         0.569   0.657    0    -6.639       0.0425        0.1080
# 0         0.622   0.501    0    -7.325       0.0816        0.7830
# 0         0.602   0.824    0    -4.087       0.0547        0.0867
# 0         0.849   0.699    4    -5.193       0.0574        0.1850
# 0         0.590   0.598    7    -7.153       0.6090        0.0697
# 0         0.685   0.572    0    -5.685       0.1470        0.1100
# 0         0.714   0.582    5    -7.272       0.0808        0.0129
# 0         0.500   0.515    7    -8.283       0.3100        0.4420
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000000    0.1190   0.4710  131.896
# 0          0.000000    0.2830   0.5950  134.985
# 0          0.000000    0.1100   0.9640   88.894
# 0          0.000000    0.0863   0.4630  105.020
# 0          0.000000    0.1680   0.8150  113.033
# 0          0.000002    0.1240   0.5700   94.030
# 0          0.000024    0.0715   0.7500   95.864
# 0          0.000000    0.1080   0.1110   73.008
# 0          0.000004    0.3010   0.5120   81.478
# 0          0.000000    0.0947   0.4420  125.147
# 0          0.001180    0.0954   0.0778  100.989
# 0          0.000000    0.1120   0.3400  156.073
# 0          0.000000    0.1830   0.2750  117.336
# 0          0.000000    0.0774   0.3380   92.819
# 0          0.000180    0.0681   0.5660   85.173

# %%
from datetime import datetime
currentMonth = datetime.now().month
season = 0
if currentMonth in [12,1,2]:
    season = 1
    stats['1'] = 1
    stats['2'] = 0
    stats['3'] = 0
    stats['4'] = 0
elif currentMonth in [3,4,5]:
    season = 2
    stats['1'] = 0
    stats['2'] = 1
    stats['3'] = 0
    stats['4'] = 0
elif currentMonth in [6,7,8]:
    season = 3
    stats['1'] = 0
    stats['2'] = 0
    stats['3'] = 1
    stats['4'] = 0
elif currentMonth in [9,10,11]:
    season = 4
    stats['1'] = 0
    stats['2'] = 0
    stats['3'] = 0
    stats['4'] = 1

# %%
stats['trackName'] = list(df['trackName'])

# %%
stats.to_csv('Data/Playlist_Data/playlist_stats.csv')

# %%
stats.head(5)
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.436   0.655    1    -8.370       0.0583        0.4990
# 0         0.603   0.784    6    -4.023       0.0620        0.4460
# 0         0.913   0.603    8    -4.892       0.2260        0.0272
# 0         0.586   0.893    7    -8.772       0.4390        0.8270
# 0         0.535   0.388    7    -9.805       0.1550        0.5070
#
#    instrumentalness  liveness  valence    tempo  1  2  3  4    trackName
# 0          0.000008     0.688    0.412  121.002  0  1  0  0    Good Days
# 0          0.000008     0.119    0.769  172.041  0  1  0  0     Dark Red
# 0          0.000503     0.167    0.497  123.061  0  1  0  0         Lost
# 0          0.642000     0.212    0.650  140.023  0  1  0  0  Funny Thing
# 0          0.000000     0.110    0.412  106.703  0  1  0  0     I Hate U
